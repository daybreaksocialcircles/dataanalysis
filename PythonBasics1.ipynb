# %% [markdown]
# <a href="https://colab.research.google.com/github/daybreaksocialcircles/dataanalysis/blob/master/PythonBasics1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab ~= Jupyter Notebook in the Cloud
#
#
# *   Pro: No install required
# *   Con: Don't put your PHI data on Google Drive

# %%
print("Kyle is awesome")
print("Jim is fantastic")
print("Chris is the best")
print("Mark is even better")
# Out:
# Kyle is awesome
# Jim is fantastic
# Chris is the best
# Mark is even better

# %%
import re 
for test_string in ['555-1212', '777-ISBAD', 'john.smith@gmail.com']:
  if re.match(r'^\d{3}-\d{4}$', test_string):
    print(test_string, ' is a valid US local phone number')
  else:
    print('Rejected: ', test_string)
# Out:
# 555-1212  is a valid US local phone number
# Rejected:  777-ISBAD
# Rejected:  john.weeks@gmail.com
